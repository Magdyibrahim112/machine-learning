# %% [markdown]
# <a href="https://colab.research.google.com/github/Magdyibrahim112/machine-learning/blob/main/ML_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# THIS IS FILE 1
